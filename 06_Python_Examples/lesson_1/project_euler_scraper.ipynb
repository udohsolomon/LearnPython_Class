# %%
#!/usr/bin/env python
import os
from bs4 import BeautifulSoup
from urllib import request
import sys
import json
from threading import Thread
import queue
from warnings import warn

with open('languages.json') as f:
    LANGUAGES = json.load(f)

LEGAL_CHARS = 'abcdefghijklmnopqrstuvwxyz01234567890_-'
LAST_PROB = 640
URL_ROOT = 'http://projecteuler.net/problem={}'
THREADS = 5

# out_path, language = sys.argv[1:]

out_path = 'tst'
language = 'javascript'

ext, comment = LANGUAGES[language]

print('Ensuring path exists: {}'.format(out_path))
os.makedirs(out_path, exist_ok=True)

def fetch_problem(num):
    print('Fetching problem {} of {}...'.format(num, LAST_PROB))
    url = URL_ROOT.format(num)

    soup = BeautifulSoup(request.urlopen(url).read().decode())

    title = soup.find_all('h2')[0].text
    file_title = ''.join(char for char in '_'.join(title.split()).lower() if char in LEGAL_CHARS)

    filepath = os.path.join(out_path, '{:03}-{}{}'.format(num, file_title, ext))

    content = soup.find_all('div', {'class': 'problem_content'})[0]

    lines = [line for line in content.text.split('\n') if line]

    comment_text = ['{} {}'.format(comment, line) for line in [title.upper(), url] + lines]

    if os.path.exists(filepath):
        warn('File {} already exists: skipping.'.format(filepath))
        return

    # print('\tSaving problem at {}'.format(filepath))

    with open(filepath, 'w') as f:
        f.write('\n'.join(comment_text))


def worker():
    while True:
        item = q.get()
        if item is None:
            break
        fetch_problem(item)
        q.task_done()

q = queue.Queue()
threads = []
for i in range(THREADS):
    t = Thread(target=worker)
    t.start()
    threads.append(t)

for item in range(1, LAST_PROB+1):
    q.put(item)

# block until all tasks are done
q.join()

# stop workers
for _ in range(THREADS):
    q.put(None)
for t in threads:
    t.join()
# Out:
# Ensuring path exists: tst
# Fetching problem 1 of 640...
# Fetching problem 2 of 640...
# Fetching problem 3 of 640...
# Fetching problem 4 of 640...
# Fetching problem 5 of 640...
# Fetching problem 6 of 640...
# Fetching problem 7 of 640...
# Fetching problem 8 of 640...
# Fetching problem 9 of 640...
# Fetching problem 10 of 640...
# Fetching problem 11 of 640...Fetching problem 12 of 640...
#
# Fetching problem 13 of 640...
# Fetching problem 14 of 640...
# Fetching problem 15 of 640...
# Fetching problem 16 of 640...
# Fetching problem 17 of 640...
# Fetching problem 18 of 640...
# Fetching problem 19 of 640...
# Fetching problem 20 of 640...
# Fetching problem 21 of 640...
# Fetching problem 22 of 640...
# Fetching problem 23 of 640...
# Fetching problem 24 of 640...
# Fetching problem 25 of 640...
# Fetching problem 26 of 640...
# Fetching problem 27 of 640...
# Fetching problem 28 of 640...
# Fetching problem 29 of 640...
# Fetching problem 30 of 640...
# Fetching problem 31 of 640...
# Fetching problem 32 of 640...
# Fetching problem 33 of 640...
# Fetching problem 34 of 640...
# Fetching problem 35 of 640...
# Fetching problem 36 of 640...
# Fetching problem 37 of 640...
# Fetching problem 38 of 640...
# Fetching problem 39 of 640...
# Fetching problem 40 of 640...
# Fetching problem 41 of 640...Fetching problem 42 of 640...
#
# Fetching problem 43 of 640...
# Fetching problem 44 of 640...
# Fetching problem 45 of 640...
# Fetching problem 46 of 640...
# Fetching problem 47 of 640...
# Fetching problem 48 of 640...
# Fetching problem 49 of 640...
# Fetching problem 50 of 640...
# Fetching problem 51 of 640...
# Fetching problem 52 of 640...
# Fetching problem 53 of 640...
# Fetching problem 54 of 640...
# Fetching problem 55 of 640...
# Fetching problem 56 of 640...
# Fetching problem 57 of 640...
# Fetching problem 58 of 640...
# Fetching problem 59 of 640...
# Fetching problem 60 of 640...
# Fetching problem 61 of 640...
# Fetching problem 62 of 640...
# Fetching problem 63 of 640...
# Fetching problem 64 of 640...
# Fetching problem 65 of 640...
# Fetching problem 66 of 640...
# Fetching problem 67 of 640...
# Fetching problem 68 of 640...
# Fetching problem 69 of 640...
# Fetching problem 70 of 640...
# Fetching problem 71 of 640...Fetching problem 72 of 640...
#
# Fetching problem 73 of 640...
# Fetching problem 74 of 640...
# Fetching problem 75 of 640...
# Fetching problem 76 of 640...
# Fetching problem 77 of 640...
# Fetching problem 78 of 640...
# Fetching problem 79 of 640...Fetching problem 80 of 640...
#
# Fetching problem 81 of 640...
# Fetching problem 82 of 640...
# Fetching problem 83 of 640...
# Fetching problem 84 of 640...
# Fetching problem 85 of 640...
# Fetching problem 86 of 640...
# Fetching problem 87 of 640...
# Fetching problem 88 of 640...
# Fetching problem 89 of 640...
# Fetching problem 90 of 640...
# Fetching problem 91 of 640...
# Fetching problem 92 of 640...
# Fetching problem 93 of 640...
# Fetching problem 94 of 640...Fetching problem 95 of 640...
#
# Fetching problem 96 of 640...
# Fetching problem 97 of 640...
# Fetching problem 98 of 640...
# Fetching problem 99 of 640...Fetching problem 100 of 640...
#
# Fetching problem 101 of 640...
# Fetching problem 102 of 640...
# Fetching problem 103 of 640...Fetching problem 104 of 640...
#
# Fetching problem 105 of 640...
# Fetching problem 106 of 640...
# Fetching problem 107 of 640...
# Fetching problem 108 of 640...
# Fetching problem 109 of 640...
# Fetching problem 110 of 640...
# Fetching problem 111 of 640...
# Fetching problem 112 of 640...
# Fetching problem 113 of 640...
# Fetching problem 114 of 640...
# Fetching problem 115 of 640...
# Fetching problem 116 of 640...
# Fetching problem 117 of 640...
# Fetching problem 118 of 640...
# Fetching problem 119 of 640...
# Fetching problem 120 of 640...
# Fetching problem 121 of 640...
# Fetching problem 122 of 640...
# Fetching problem 123 of 640...
# Fetching problem 124 of 640...
# Fetching problem 125 of 640...
# Fetching problem 126 of 640...
# Fetching problem 127 of 640...
# Fetching problem 128 of 640...
# Fetching problem 129 of 640...
# Fetching problem 130 of 640...
# Fetching problem 131 of 640...
# Fetching problem 132 of 640...
# Fetching problem 133 of 640...
# Fetching problem 134 of 640...
# Fetching problem 135 of 640...
# Fetching problem 136 of 640...
# Fetching problem 137 of 640...
# Fetching problem 138 of 640...
# Fetching problem 139 of 640...
# Fetching problem 140 of 640...Fetching problem 141 of 640...
#
# Fetching problem 142 of 640...
# Fetching problem 143 of 640...
# Fetching problem 144 of 640...
# Fetching problem 145 of 640...
# Fetching problem 146 of 640...
# Fetching problem 147 of 640...
# Fetching problem 148 of 640...
# Fetching problem 149 of 640...
# Fetching problem 150 of 640...
# Fetching problem 151 of 640...Fetching problem 152 of 640...
#
# Fetching problem 153 of 640...
# Fetching problem 154 of 640...
# Fetching problem 155 of 640...
# Fetching problem 156 of 640...
# Fetching problem 157 of 640...
# Fetching problem 158 of 640...
# Fetching problem 159 of 640...
# Fetching problem 160 of 640...
# Fetching problem 161 of 640...
# Fetching problem 162 of 640...
# Fetching problem 163 of 640...
# Fetching problem 164 of 640...
# Fetching problem 165 of 640...
# Fetching problem 166 of 640...
# Fetching problem 167 of 640...
# Fetching problem 168 of 640...
# Fetching problem 169 of 640...
# Fetching problem 170 of 640...
# Fetching problem 171 of 640...
# Fetching problem 172 of 640...
# Fetching problem 173 of 640...
# Fetching problem 174 of 640...
# Fetching problem 175 of 640...
# Fetching problem 176 of 640...
# Fetching problem 177 of 640...
# Fetching problem 178 of 640...
# Fetching problem 179 of 640...
# Fetching problem 180 of 640...
# Fetching problem 181 of 640...
# Fetching problem 182 of 640...
# Fetching problem 183 of 640...
# Fetching problem 184 of 640...
# Fetching problem 185 of 640...
# Fetching problem 186 of 640...
# Fetching problem 187 of 640...
# Fetching problem 188 of 640...Fetching problem 189 of 640...
#
# Fetching problem 190 of 640...
# Fetching problem 191 of 640...
# Fetching problem 192 of 640...
# Fetching problem 193 of 640...
# Fetching problem 194 of 640...
# Fetching problem 195 of 640...
# Fetching problem 196 of 640...
# Fetching problem 197 of 640...
# Fetching problem 198 of 640...
# Fetching problem 199 of 640...
# Fetching problem 200 of 640...
# Fetching problem 201 of 640...
# Fetching problem 202 of 640...
# Fetching problem 203 of 640...
# Fetching problem 204 of 640...
# Fetching problem 205 of 640...
# Fetching problem 206 of 640...
# Fetching problem 207 of 640...
# Fetching problem 208 of 640...
# Fetching problem 209 of 640...Fetching problem 210 of 640...Fetching problem 211 of 640...
#
#
# Fetching problem 212 of 640...
# Fetching problem 213 of 640...Fetching problem 214 of 640...
#
# Fetching problem 215 of 640...
# Fetching problem 216 of 640...
# Fetching problem 217 of 640...
# Fetching problem 218 of 640...
# Fetching problem 219 of 640...
# Fetching problem 220 of 640...
# Fetching problem 221 of 640...
# Fetching problem 222 of 640...
# Fetching problem 223 of 640...Fetching problem 224 of 640...
# Fetching problem 225 of 640...Fetching problem 226 of 640...
#
#
# Fetching problem 227 of 640...
# Fetching problem 228 of 640...Fetching problem 229 of 640...Fetching problem 230 of 640...
#
# Fetching problem 231 of 640...
#
# Fetching problem 232 of 640...
# Fetching problem 233 of 640...
# Fetching problem 234 of 640...
# Fetching problem 235 of 640...
# Fetching problem 236 of 640...
# Fetching problem 237 of 640...
# Fetching problem 238 of 640...
# Fetching problem 239 of 640...
# Fetching problem 240 of 640...
# Fetching problem 241 of 640...Fetching problem 242 of 640...
#
# Fetching problem 243 of 640...
# Fetching problem 244 of 640...
# Fetching problem 245 of 640...
# Fetching problem 246 of 640...
# Fetching problem 247 of 640...
# Fetching problem 248 of 640...
# Fetching problem 249 of 640...
# Fetching problem 250 of 640...
# Fetching problem 251 of 640...
# Fetching problem 252 of 640...
# Fetching problem 253 of 640...
# Fetching problem 254 of 640...
# Fetching problem 255 of 640...
# Fetching problem 256 of 640...
# Fetching problem 257 of 640...
# Fetching problem 258 of 640...
# Fetching problem 259 of 640...
# Fetching problem 260 of 640...
# Fetching problem 261 of 640...
# Fetching problem 262 of 640...
# Fetching problem 263 of 640...
# Fetching problem 264 of 640...
# Fetching problem 265 of 640...
# Fetching problem 266 of 640...
# Fetching problem 267 of 640...
# Fetching problem 268 of 640...
# Fetching problem 269 of 640...
# Fetching problem 270 of 640...
# Fetching problem 271 of 640...
# Fetching problem 272 of 640...
# Fetching problem 273 of 640...
# Fetching problem 274 of 640...
# Fetching problem 275 of 640...
# Fetching problem 276 of 640...
# Fetching problem 277 of 640...
# Fetching problem 278 of 640...
# Fetching problem 279 of 640...
# Fetching problem 280 of 640...
# Fetching problem 281 of 640...
# Fetching problem 282 of 640...
# Fetching problem 283 of 640...
# Fetching problem 284 of 640...
# Fetching problem 285 of 640...
# Fetching problem 286 of 640...
# Fetching problem 287 of 640...
# Fetching problem 288 of 640...
# Fetching problem 289 of 640...
# Fetching problem 290 of 640...Fetching problem 291 of 640...
#
# Fetching problem 292 of 640...
# Fetching problem 293 of 640...
# Fetching problem 294 of 640...
# Fetching problem 295 of 640...
# Fetching problem 296 of 640...
# Fetching problem 297 of 640...
# Fetching problem 298 of 640...
# Fetching problem 299 of 640...
# Fetching problem 300 of 640...Fetching problem 301 of 640...
#
# Fetching problem 302 of 640...
# Fetching problem 303 of 640...
# Fetching problem 304 of 640...
# Fetching problem 305 of 640...Fetching problem 306 of 640...
#
# Fetching problem 307 of 640...
# Fetching problem 308 of 640...
# Fetching problem 309 of 640...Fetching problem 310 of 640...
#
# Fetching problem 311 of 640...
# Fetching problem 312 of 640...
# Fetching problem 313 of 640...
# Fetching problem 314 of 640...
# Fetching problem 315 of 640...
# Fetching problem 316 of 640...
# Fetching problem 317 of 640...
# Fetching problem 318 of 640...
# Fetching problem 319 of 640...Fetching problem 320 of 640...
#
# Fetching problem 321 of 640...
# Fetching problem 322 of 640...
# Fetching problem 323 of 640...
# Fetching problem 324 of 640...
# Fetching problem 325 of 640...Fetching problem 326 of 640...
#
# Fetching problem 327 of 640...
# Fetching problem 328 of 640...
# Fetching problem 329 of 640...
# Fetching problem 330 of 640...
# Fetching problem 331 of 640...
# Fetching problem 332 of 640...
# Fetching problem 333 of 640...
# Fetching problem 334 of 640...
# Fetching problem 335 of 640...Fetching problem 336 of 640...
#
# Fetching problem 337 of 640...
# Fetching problem 338 of 640...
# Fetching problem 339 of 640...
# Fetching problem 340 of 640...Fetching problem 341 of 640...
#
# Fetching problem 342 of 640...
# Fetching problem 343 of 640...
# Fetching problem 344 of 640...
# Fetching problem 345 of 640...
# Fetching problem 346 of 640...
# Fetching problem 347 of 640...
# Fetching problem 348 of 640...
# Fetching problem 349 of 640...
# Fetching problem 350 of 640...
# Fetching problem 351 of 640...
# Fetching problem 352 of 640...
# Fetching problem 353 of 640...
# Fetching problem 354 of 640...
# Fetching problem 355 of 640...
# Fetching problem 356 of 640...
# Fetching problem 357 of 640...
# Fetching problem 358 of 640...
# Fetching problem 359 of 640...
# Fetching problem 360 of 640...
# Fetching problem 361 of 640...
# Fetching problem 362 of 640...
# Fetching problem 363 of 640...
# Fetching problem 364 of 640...
# Fetching problem 365 of 640...
# Fetching problem 366 of 640...
# Fetching problem 367 of 640...
# Fetching problem 368 of 640...
# Fetching problem 369 of 640...
# Fetching problem 370 of 640...
# Fetching problem 371 of 640...
# Fetching problem 372 of 640...
# Fetching problem 373 of 640...
# Fetching problem 374 of 640...
# Fetching problem 375 of 640...
# Fetching problem 376 of 640...
# Fetching problem 377 of 640...
# Fetching problem 378 of 640...
# Fetching problem 379 of 640...
# Fetching problem 380 of 640...
# Fetching problem 381 of 640...
# Fetching problem 382 of 640...
# Fetching problem 383 of 640...
# Fetching problem 384 of 640...
# Fetching problem 385 of 640...Fetching problem 386 of 640...
#
# Fetching problem 387 of 640...
# Fetching problem 388 of 640...Fetching problem 389 of 640...
#
# Fetching problem 390 of 640...
# Fetching problem 391 of 640...
# Fetching problem 392 of 640...
# Fetching problem 393 of 640...
# Fetching problem 394 of 640...
# Fetching problem 395 of 640...
# Fetching problem 396 of 640...
# Fetching problem 397 of 640...
# Fetching problem 398 of 640...
# Fetching problem 399 of 640...
# Fetching problem 400 of 640...
# Fetching problem 401 of 640...
# Fetching problem 402 of 640...
# Fetching problem 403 of 640...Fetching problem 404 of 640...
#
# Fetching problem 405 of 640...
# Fetching problem 406 of 640...
# Fetching problem 407 of 640...
# Fetching problem 408 of 640...
# Fetching problem 409 of 640...
# Fetching problem 410 of 640...
# Fetching problem 411 of 640...
# Fetching problem 412 of 640...
# Fetching problem 413 of 640...
# Fetching problem 414 of 640...
# Fetching problem 415 of 640...
# Fetching problem 416 of 640...
# Fetching problem 417 of 640...
# Fetching problem 418 of 640...
# Fetching problem 419 of 640...
# Fetching problem 420 of 640...Fetching problem 421 of 640...
#
# Fetching problem 422 of 640...
# Fetching problem 423 of 640...
# Fetching problem 424 of 640...
# Fetching problem 425 of 640...
# Fetching problem 426 of 640...
# Fetching problem 427 of 640...
# Fetching problem 428 of 640...
# Fetching problem 429 of 640...
# Fetching problem 430 of 640...
# Fetching problem 431 of 640...
# Fetching problem 432 of 640...
# Fetching problem 433 of 640...Fetching problem 434 of 640...
#
# Fetching problem 435 of 640...
# Fetching problem 436 of 640...
# Fetching problem 437 of 640...
# Fetching problem 438 of 640...
# Fetching problem 439 of 640...
# Fetching problem 440 of 640...Fetching problem 441 of 640...
#
# Fetching problem 442 of 640...
# Fetching problem 443 of 640...
# Fetching problem 444 of 640...
# Fetching problem 445 of 640...
# Fetching problem 446 of 640...
# Fetching problem 447 of 640...
# Fetching problem 448 of 640...
# Fetching problem 449 of 640...
# Fetching problem 450 of 640...
# Fetching problem 451 of 640...
# Fetching problem 452 of 640...
# Fetching problem 453 of 640...
# Fetching problem 454 of 640...
# Fetching problem 455 of 640...
# Fetching problem 456 of 640...
# Fetching problem 457 of 640...
# Fetching problem 458 of 640...
# Fetching problem 459 of 640...
# Fetching problem 460 of 640...
# Fetching problem 461 of 640...
# Fetching problem 462 of 640...
# Fetching problem 463 of 640...
# Fetching problem 464 of 640...
# Fetching problem 465 of 640...
# Fetching problem 466 of 640...
# Fetching problem 467 of 640...
# Fetching problem 468 of 640...
# Fetching problem 469 of 640...
# Fetching problem 470 of 640...
# Fetching problem 471 of 640...
# Fetching problem 472 of 640...
# Fetching problem 473 of 640...Fetching problem 474 of 640...
#
# Fetching problem 475 of 640...
# Fetching problem 476 of 640...
# Fetching problem 477 of 640...Fetching problem 478 of 640...
#
# Fetching problem 479 of 640...
# Fetching problem 480 of 640...
# Fetching problem 481 of 640...
# Fetching problem 482 of 640...
# Fetching problem 483 of 640...
# Fetching problem 484 of 640...
# Fetching problem 485 of 640...Fetching problem 486 of 640...
#
# Fetching problem 487 of 640...
# Fetching problem 488 of 640...Fetching problem 489 of 640...
#
# Fetching problem 490 of 640...
# Fetching problem 491 of 640...
# Fetching problem 492 of 640...
# Fetching problem 493 of 640...
# Fetching problem 494 of 640...
# Fetching problem 495 of 640...
# Fetching problem 496 of 640...
# Fetching problem 497 of 640...
# Fetching problem 498 of 640...
# Fetching problem 499 of 640...
# Fetching problem 500 of 640...
# Fetching problem 501 of 640...Fetching problem 502 of 640...
#
# Fetching problem 503 of 640...
# Fetching problem 504 of 640...
# Fetching problem 505 of 640...
# Fetching problem 506 of 640...
# Fetching problem 507 of 640...
# Fetching problem 508 of 640...
# Fetching problem 509 of 640...
# Fetching problem 510 of 640...
# Fetching problem 511 of 640...
# Fetching problem 512 of 640...
# Fetching problem 513 of 640...
# Fetching problem 514 of 640...
# Fetching problem 515 of 640...
# Fetching problem 516 of 640...
# Fetching problem 517 of 640...
# Fetching problem 518 of 640...
# Fetching problem 519 of 640...
# Fetching problem 520 of 640...
# Fetching problem 521 of 640...
# Fetching problem 522 of 640...Fetching problem 523 of 640...
#
# Fetching problem 524 of 640...
# Fetching problem 525 of 640...
# Fetching problem 526 of 640...
# Fetching problem 527 of 640...Fetching problem 528 of 640...
#
# Fetching problem 529 of 640...
# Fetching problem 530 of 640...
# Fetching problem 531 of 640...
# Fetching problem 532 of 640...
# Fetching problem 533 of 640...
# Fetching problem 534 of 640...
# Fetching problem 535 of 640...
# Fetching problem 536 of 640...
# Fetching problem 537 of 640...
# Fetching problem 538 of 640...
# Fetching problem 539 of 640...
# Fetching problem 540 of 640...
# Fetching problem 541 of 640...
# Fetching problem 542 of 640...
# Fetching problem 543 of 640...
# Fetching problem 544 of 640...
# Fetching problem 545 of 640...
# Fetching problem 546 of 640...
# Fetching problem 547 of 640...
# Fetching problem 548 of 640...
# Fetching problem 549 of 640...
# Fetching problem 550 of 640...
# Fetching problem 551 of 640...
# Fetching problem 552 of 640...
# Fetching problem 553 of 640...
# Fetching problem 554 of 640...
# Fetching problem 555 of 640...
# Fetching problem 556 of 640...
# Fetching problem 557 of 640...
# Fetching problem 558 of 640...
# Fetching problem 559 of 640...
# Fetching problem 560 of 640...
# Fetching problem 561 of 640...Fetching problem 562 of 640...
#
# Fetching problem 563 of 640...
# Fetching problem 564 of 640...
# Fetching problem 565 of 640...
# Fetching problem 566 of 640...
# Fetching problem 567 of 640...
# Fetching problem 568 of 640...
# Fetching problem 569 of 640...
# Fetching problem 570 of 640...
# Fetching problem 571 of 640...
# Fetching problem 572 of 640...Fetching problem 573 of 640...
#
# Fetching problem 574 of 640...
# Fetching problem 575 of 640...
# Fetching problem 576 of 640...Fetching problem 577 of 640...
#
# Fetching problem 578 of 640...
# Fetching problem 579 of 640...Fetching problem 580 of 640...
#
# Fetching problem 581 of 640...
# Fetching problem 582 of 640...
# Fetching problem 583 of 640...
# Fetching problem 584 of 640...
# Fetching problem 585 of 640...
# Fetching problem 586 of 640...
# Fetching problem 587 of 640...
# Fetching problem 588 of 640...
# Fetching problem 589 of 640...
# Fetching problem 590 of 640...
# Fetching problem 591 of 640...
# Fetching problem 592 of 640...
# Fetching problem 593 of 640...
# Fetching problem 594 of 640...
# Fetching problem 595 of 640...
# Fetching problem 596 of 640...
# Fetching problem 597 of 640...
# Fetching problem 598 of 640...
# Fetching problem 599 of 640...
# Fetching problem 600 of 640...
# Fetching problem 601 of 640...
# Fetching problem 602 of 640...
# Fetching problem 603 of 640...
# Fetching problem 604 of 640...
# Fetching problem 605 of 640...Fetching problem 606 of 640...
#
# Fetching problem 607 of 640...
# Fetching problem 608 of 640...
# Fetching problem 609 of 640...Fetching problem 610 of 640...
#
# Fetching problem 611 of 640...
# Fetching problem 612 of 640...
# Fetching problem 613 of 640...
# Fetching problem 614 of 640...
# Fetching problem 615 of 640...
# Fetching problem 616 of 640...
# Fetching problem 617 of 640...
# Fetching problem 618 of 640...Fetching problem 619 of 640...
#
# Fetching problem 620 of 640...
# Fetching problem 621 of 640...
# Fetching problem 622 of 640...
# Fetching problem 623 of 640...
# Fetching problem 624 of 640...
# Fetching problem 625 of 640...
# Fetching problem 626 of 640...
# Fetching problem 627 of 640...
# Fetching problem 628 of 640...
# Fetching problem 629 of 640...
# Fetching problem 630 of 640...Fetching problem 631 of 640...
#
# Fetching problem 632 of 640...
# Fetching problem 633 of 640...
# Fetching problem 634 of 640...
# Fetching problem 635 of 640...
# Fetching problem 636 of 640...
# Fetching problem 637 of 640...
# Fetching problem 638 of 640...Fetching problem 639 of 640...
#
# Fetching problem 640 of 640...
